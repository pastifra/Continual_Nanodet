# %%
import argparse
import os
import warnings
import yaml

import pytorch_lightning as pl
import torch
from pytorch_lightning.callbacks import TQDMProgressBar
from pytorch_lightning.accelerators import find_usable_cuda_devices
from torchvision import datasets
from torch.utils.data import Dataset, DataLoader
from nanodet.data.collate import naive_collate
from nanodet.data.dataset import build_dataset
from nanodet.evaluator import build_evaluator
from nanodet.trainer.task import TrainingTask
from torchvision.transforms import ToTensor, ToPILImage
from nanodet.util import (
    NanoDetLightningLogger,
    cfg,
    convert_old_model,
    env_utils,
    load_config,
    load_model_weight,
    mkdir,
)
import random
from torch.utils.data import Subset
from IPython.display import Image
from IPython.display import display
from nanodet.data.dataset.coco import CocoDataset

#Set logger and seed
logger = NanoDetLightningLogger('test')
pl.seed_everything(1234)
# Out:
# Global seed set to 1234
# 1234

# %%
#Classes to handle the datasets in the replay scenario

class ReplayDataLoader:
    def __init__(self, dataset1, dataset2, batch_size, shuffle):
        """
        This class is used to create a dataloader that creates batches
        using the task specific dataset and the replay buffer dataset.
        Batches are created using 50% of the task specific dataset and 50% of the replay buffer dataset.
        The iterators are reset when the task specific dataset is exhausted.
        If the replay buffer dataset is exhausted before the task specific dataset, its iterator is reset.
        
        Args:
            dataset1: task specific dataset
            dataset2: replay buffer dataset
            batch_size: Batch size
            shuffle: Whether to shuffle the data
        """
        
        self.dataset1 = dataset1
        self.dataset2 = dataset2
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.dataset1_loader = torch.utils.data.DataLoader(
            self.dataset1,
            batch_size=self.batch_size//2,
            shuffle=self.shuffle,
            num_workers=8,
            pin_memory=True,
            collate_fn=naive_collate,
            drop_last=True,
        )
        self.dataset2_loader = torch.utils.data.DataLoader(
            self.dataset2,
            batch_size=self.batch_size//2,
            shuffle=self.shuffle,
            num_workers=8,
            pin_memory=True,
            collate_fn=naive_collate,
            drop_last=True,
        )
    
    def __iter__(self):
        self.dataset1_iter = iter(self.dataset1_loader)
        self.dataset2_iter = iter(self.dataset2_loader)
        return self
    
    def __next__(self):
        try:
            batch1 = next(self.dataset1_iter)
        except StopIteration:
            raise StopIteration
        try:
            batch2 = next(self.dataset2_iter)
        except StopIteration:
            self.dataset2_iter = iter(self.dataset2_loader)
            batch2 = next(self.dataset2_iter)
            
        merged_batch = {}
        for key in batch1.keys():
            if key == 'img':
                merged_batch[key] = batch1[key] + batch2[key]
            elif key == 'img_info':
                merged_batch[key] = {k: batch1[key][k] + batch2[key][k] for k in batch1[key]}
            elif key in ['gt_bboxes', 'gt_labels', 'gt_bboxes_ignore', 'warp_matrix']:
                #merged_batch[key] = [torch.cat((torch.tensor(b1), torch.tensor(b2))) for b1, b2 in zip(batch1[key], batch2[key])]
                merged_batch[key] = batch1[key] + batch2[key]
            else:
                raise ValueError(f"Key not recognized")
        
        return merged_batch
    
    def __len__(self):
        return len(self.dataset1)
        
class SmartBufferDataset(Dataset):
    """
    This class is used to create a replay buffer dataset that stores random samples of the task specific dataset.
    At init it takes random samples of the first task dataset to fill the buffer.
    Then from task n to task n+1 it, where n>0, it updates 50% of the buffer with the new task dataset.
    
    Args:
        dataset_n: task specific dataset
        buffer_size: size of the replay buffer
    """
    def __init__(self, dataset_n, buffer_size=250):
        self.buffer_size = buffer_size
        #At initialization, take random samples of the task 0 dataset to fill the buffer
        self.buffer_indices = random.sample(range(len(dataset_n)), self.buffer_size)
        self.buffer_dataset = Subset(dataset_n, self.buffer_indices)

    def __getitem__(self, buff_index):
        #Just return a buffer item at the index
        return self.buffer_dataset[buff_index]

    def __len__(self):
        #Return the buffer size
        return self.buffer_size

    def update_buffer(self, dataset_np1, cfg):
        #Smart update, based on the number of classes already contained in the buffer and the ones that are being added to the dataset
        #E.g. Update only 1/16 of the buffer if only 1 new class is added to the dataset and the buffer contains 15 classes
        new_classes = len(cfg.data.train.class_names)
        val_classes = len(cfg.data.val.class_names)
        ideal_samples_per_class = int(self.buffer_size/val_classes)
        update_buffer_indices_n = random.sample(range(self.buffer_size), self.buffer_size - int(ideal_samples_per_class*new_classes))
        update_buffer_indices_np1 = random.sample(range(len(dataset_np1)), int(ideal_samples_per_class*new_classes))
        subset_n = Subset(self.buffer_dataset, update_buffer_indices_n)
        subset_np1 = Subset(dataset_np1, update_buffer_indices_np1)
        self.buffer_dataset = torch.utils.data.ConcatDataset([subset_n, subset_np1])

# %%
#Function to create the task configuration file required for training
def create_exp_cfg(yml_path, task):
    all_names = ["aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]
    #Load the YAML file
    with open(yml_path, 'r') as file:
        temp_cfg = yaml.safe_load(file)
    #Save dir of the model
    temp_cfg['save_dir'] = 'models/task' + str(task)
    #If base task, training and testing classes are the same
    if task == 0:
        temp_cfg['data']['train']['class_names'] = all_names[:15]
        temp_cfg['data']['val']['class_names'] = all_names[:15]
        temp_cfg['model']['arch']['head']['num_classes'] = 20 #15
        #temp_cfg['model']['arch']['aux_head']['num_classes'] = 20 #15
    #Else, training only on task specific class, and testing on all classes
    else:
        temp_cfg['data']['train']['class_names'] = [all_names[14+task]]
        temp_cfg['data']['val']['class_names'] = all_names[:15+task]
        temp_cfg['model']['arch']['head']['num_classes'] = 20#15+task
        #temp_cfg['model']['arch']['aux_head']['num_classes'] = 20#15+task
        temp_cfg['schedule']['load_model'] = 'models/task' + str(task-1) + '/model_last.ckpt'
        
    temp_cfg_name = 'cfg/task' + str(task) + '.yml'
    print(temp_cfg_name)
    #Save the new configuration file
    with open(temp_cfg_name, 'w') as file:
        yaml.safe_dump(temp_cfg, file)

# %%
####TEMP INITIALIZATION since the base model is already available
task = 0
create_exp_cfg('cfg/VOC.yml', task)
load_config(cfg, 'cfg/task' + str(task) + '.yml')
#Build datasets and dataloaders based on the task configuration file
train_dataset = build_dataset(cfg.data.train, "train")
#val_dataset = build_dataset(cfg.data.val, "test")
buffer_dataset = SmartBufferDataset(train_dataset)
# Out:
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'aeroplane', 'id': 1, 'name': 'aeroplane'}, {'supercategory': 'bicycle', 'id': 2, 'name': 'bicycle'}, {'supercategory': 'bird', 'id': 3, 'name': 'bird'}, {'supercategory': 'boat', 'id': 4, 'name': 'boat'}, {'supercategory': 'bottle', 'id': 5, 'name': 'bottle'}, {'supercategory': 'bus', 'id': 6, 'name': 'bus'}, {'supercategory': 'car', 'id': 7, 'name': 'car'}, {'supercategory': 'cat', 'id': 8, 'name': 'cat'}, {'supercategory': 'chair', 'id': 9, 'name': 'chair'}, {'supercategory': 'cow', 'id': 10, 'name': 'cow'}, {'supercategory': 'diningtable', 'id': 11, 'name': 'diningtable'}, {'supercategory': 'dog', 'id': 12, 'name': 'dog'}, {'supercategory': 'horse', 'id': 13, 'name': 'horse'}, {'supercategory': 'motorbike', 'id': 14, 'name': 'motorbike'}, {'supercategory': 'person', 'id': 15, 'name': 'person'}]!
# cfg/task0.yml
# Load 4502 xml files and 13564 boxes
# creating index...
# index created!

# %%
###LEARNING STREAM###
#task 0: train on first 15 classes, test on 15 classes
#task 1: train on class n°16, test on 16 classes
#task 2: train on class n°17, test on 17 classes
#task 3: train on class n°18, test on 18 classes
#task 4: train on class n°19, test on 19 classes
#task 5: train on class n°20, test on 20 classes
for task in range (1, 6):
    logger = NanoDetLightningLogger('run_logs/task'+str(task))
    logger.info("Starting task" + str(task))
    logger.info("Setting up data...")
    #Create the task configuration file based on the task number and load the configuration
    create_exp_cfg('cfg/VOC.yml', task)
    load_config(cfg, 'cfg/task' + str(task) + '.yml')
    #Build datasets and dataloaders based on the task configuration file
    train_dataset = build_dataset(cfg.data.train, "train")
    #If task is not 0, create the replay dataset using the buffer
    if task == 0:
        train_dataloader = torch.utils.data.DataLoader(
            train_dataset,
            batch_size=cfg.device.batchsize_per_gpu,
            shuffle=True if task == 0 else False, #Shuffling is done inside ReplayDataset class
            num_workers=cfg.device.workers_per_gpu,
            pin_memory=True,
            collate_fn=naive_collate,
            drop_last=True,
        )
    else:
        train_dataloader = ReplayDataLoader(
            train_dataset, 
            buffer_dataset, 
            cfg.device.batchsize_per_gpu,
            shuffle = True
        )

    val_dataset = build_dataset(cfg.data.val, "test")
    val_dataloader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=cfg.device.batchsize_per_gpu,
        shuffle=False,
        num_workers=cfg.device.workers_per_gpu,
        pin_memory=True,
        collate_fn=naive_collate,
        drop_last=False,
    )
    evaluator = build_evaluator(cfg.evaluator, val_dataset)
    
    #Create the model based on the task configuration file
    logger.info("Creating model...")
    TrainTask = TrainingTask(cfg, evaluator)
    #Load the model weights if task is not 0
    if "load_model" in cfg.schedule:
        ckpt = torch.load(cfg.schedule.load_model)
        if "pytorch-lightning_version" not in ckpt:
            warnings.warn(
                "Warning! Old .pth checkpoint is deprecated. "
                "Convert the checkpoint with tools/convert_old_checkpoint.py "
            )
            ckpt = convert_old_model(ckpt)
        load_model_weight(TrainTask.model, ckpt, logger)
        logger.info("Loaded model weight from {}".format(cfg.schedule.load_model))
    model_resume_path = (
        os.path.join(cfg.save_dir, "model_last.ckpt")
        if "resume" in cfg.schedule
        else None
    )
    #Set the device to GPU if available
    if cfg.device.gpu_ids == -1:
        logger.info("Using CPU training")
        accelerator, devices, strategy, precision = (
            "cpu",
            None,
            None,
            cfg.device.precision,
        )
    else:
        accelerator, devices, strategy, precision = (
            "gpu",
            cfg.device.gpu_ids,
            None,
            cfg.device.precision,
        )

    if devices and len(devices) > 1:
        strategy = "ddp"
        env_utils.set_multi_processing(distributed=True)

    trainer = pl.Trainer(
        default_root_dir=cfg.save_dir,
        max_epochs=cfg.schedule.total_epochs,
        check_val_every_n_epoch=cfg.schedule.val_intervals,
        accelerator=accelerator,
        devices=[2],
        log_every_n_steps=cfg.log.interval,
        num_sanity_val_steps=0,
        callbacks=[TQDMProgressBar(refresh_rate=0)],
        logger=logger,
        benchmark=cfg.get("cudnn_benchmark", True),
        gradient_clip_val=cfg.get("grad_clip", 0.0),
        strategy=strategy,
        precision=precision,
    )
    trainer.fit(TrainTask, train_dataloader, val_dataloader, ckpt_path=model_resume_path)
    
    #Replay code
    #If task is 0, initialize the replay buffer with the task 0 dataset 
    #if task > 0 update the buffer with the new task dataset
    if task == 0:
        print("Creating buffer dataset")
        buffer_dataset = SmartBufferDataset(train_dataset)
    else:
        print("Updating buffer dataset")
        buffer_dataset.update_buffer(train_dataset, cfg)
# Out:
# [NanoDet][02-09 10:22:49]INFO:Starting task1
# [NanoDet][02-09 10:22:49]INFO:Starting task1
# INFO:NanoDet:Starting task1
# [NanoDet][02-09 10:22:49]INFO:Setting up data...
# [NanoDet][02-09 10:22:49]INFO:Setting up data...
# INFO:NanoDet:Setting up data...
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'pottedplant', 'id': 16, 'name': 'pottedplant'}]!
# cfg/task1.yml
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'aeroplane', 'id': 1, 'name': 'aeroplane'}, {'supercategory': 'bicycle', 'id': 2, 'name': 'bicycle'}, {'supercategory': 'bird', 'id': 3, 'name': 'bird'}, {'supercategory': 'boat', 'id': 4, 'name': 'boat'}, {'supercategory': 'bottle', 'id': 5, 'name': 'bottle'}, {'supercategory': 'bus', 'id': 6, 'name': 'bus'}, {'supercategory': 'car', 'id': 7, 'name': 'car'}, {'supercategory': 'cat', 'id': 8, 'name': 'cat'}, {'supercategory': 'chair', 'id': 9, 'name': 'chair'}, {'supercategory': 'cow', 'id': 10, 'name': 'cow'}, {'supercategory': 'diningtable', 'id': 11, 'name': 'diningtable'}, {'supercategory': 'dog', 'id': 12, 'name': 'dog'}, {'supercategory': 'horse', 'id': 13, 'name': 'horse'}, {'supercategory': 'motorbike', 'id': 14, 'name': 'motorbike'}, {'supercategory': 'person', 'id': 15, 'name': 'person'}, {'supercategory': 'pottedplant', 'id': 16, 'name': 'pottedplant'}]!
# Load 273 xml files and 625 boxes
# creating index...
# index created!
# [NanoDet][02-09 10:22:49]INFO:Creating model...
# [NanoDet][02-09 10:22:49]INFO:Creating model...
# INFO:NanoDet:Creating model...
# Load 4530 xml files and 13606 boxes
# creating index...
# index created!
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# [NanoDet][02-09 10:22:51]INFO:Loaded model weight from models/task0/model_last.ckpt
# [NanoDet][02-09 10:22:51]INFO:Loaded model weight from models/task0/model_last.ckpt
# INFO:NanoDet:Loaded model weight from models/task0/model_last.ckpt
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
#
#   | Name  | Type        | Params
# --------------------------------------
# 0 | model | NanoDetPlus | 1.2 M
# --------------------------------------
# 1.2 M     Trainable params
# 0         Non-trainable params
# 1.2 M     Total params
# 4.699     Total estimated model params size (MB)
# /home/pasti/anaconda3/envs/nanodet/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [NanoDet][02-09 10:22:53]INFO:Train|Epoch1/100|Iter0(1/273)| mem:4.36G| lr:1.00e-07| loss_qfl:0.6390| loss_bbox:0.3069| loss_dfl:0.1807|
# [NanoDet][02-09 10:22:53]INFO:Train|Epoch1/100|Iter0(1/273)| mem:4.36G| lr:1.00e-07| loss_qfl:0.6390| loss_bbox:0.3069| loss_dfl:0.1807|
# INFO:NanoDet:Train|Epoch1/100|Iter0(1/273)| mem:4.36G| lr:1.00e-07| loss_qfl:0.6390| loss_bbox:0.3069| loss_dfl:0.1807|
# [NanoDet][02-09 10:23:07]INFO:Train|Epoch4/100|Iter25(2/273)| mem:5.13G| lr:5.01e-05| loss_qfl:0.4730| loss_bbox:0.3235| loss_dfl:0.1797|
# [NanoDet][02-09 10:23:07]INFO:Train|Epoch4/100|Iter25(2/273)| mem:5.13G| lr:5.01e-05| loss_qfl:0.4730| loss_bbox:0.3235| loss_dfl:0.1797|
# INFO:NanoDet:Train|Epoch4/100|Iter25(2/273)| mem:5.13G| lr:5.01e-05| loss_qfl:0.4730| loss_bbox:0.3235| loss_dfl:0.1797|
# [NanoDet][02-09 10:23:19]INFO:Train|Epoch7/100|Iter50(3/273)| mem:5.13G| lr:1.00e-04| loss_qfl:0.4872| loss_bbox:0.2628| loss_dfl:0.1684|
# [NanoDet][02-09 10:23:19]INFO:Train|Epoch7/100|Iter50(3/273)| mem:5.13G| lr:1.00e-04| loss_qfl:0.4872| loss_bbox:0.2628| loss_dfl:0.1684|
# INFO:NanoDet:Train|Epoch7/100|Iter50(3/273)| mem:5.13G| lr:1.00e-04| loss_qfl:0.4872| loss_bbox:0.2628| loss_dfl:0.1684|
# [NanoDet][02-09 10:23:32]INFO:Train|Epoch10/100|Iter75(4/273)| mem:5.13G| lr:1.50e-04| loss_qfl:0.4707| loss_bbox:0.2774| loss_dfl:0.1649|
# [NanoDet][02-09 10:23:32]INFO:Train|Epoch10/100|Iter75(4/273)| mem:5.13G| lr:1.50e-04| loss_qfl:0.4707| loss_bbox:0.2774| loss_dfl:0.1649|
# INFO:NanoDet:Train|Epoch10/100|Iter75(4/273)| mem:5.13G| lr:1.50e-04| loss_qfl:0.4707| loss_bbox:0.2774| loss_dfl:0.1649|
# [NanoDet][02-09 10:23:44]INFO:Train|Epoch13/100|Iter100(5/273)| mem:5.13G| lr:2.00e-04| loss_qfl:0.5210| loss_bbox:0.2697| loss_dfl:0.1676|
# [NanoDet][02-09 10:23:44]INFO:Train|Epoch13/100|Iter100(5/273)| mem:5.13G| lr:2.00e-04| loss_qfl:0.5210| loss_bbox:0.2697| loss_dfl:0.1676|
# INFO:NanoDet:Train|Epoch13/100|Iter100(5/273)| mem:5.13G| lr:2.00e-04| loss_qfl:0.5210| loss_bbox:0.2697| loss_dfl:0.1676|
# [NanoDet][02-09 10:23:57]INFO:Train|Epoch16/100|Iter125(6/273)| mem:5.13G| lr:2.50e-04| loss_qfl:0.4558| loss_bbox:0.2178| loss_dfl:0.1498|
# [NanoDet][02-09 10:23:57]INFO:Train|Epoch16/100|Iter125(6/273)| mem:5.13G| lr:2.50e-04| loss_qfl:0.4558| loss_bbox:0.2178| loss_dfl:0.1498|
# INFO:NanoDet:Train|Epoch16/100|Iter125(6/273)| mem:5.13G| lr:2.50e-04| loss_qfl:0.4558| loss_bbox:0.2178| loss_dfl:0.1498|
# INFO:NanoDet:Train|Epoch35/100|Iter275(4/273)| mem:5.13G| lr:5.50e-04| loss_qfl:0.2151| loss_bbox:0.3400| loss_dfl:0.1944|
# [NanoDet][02-09 10:25:24]INFO:Train|Epoch38/100|Iter300(5/273)| mem:5.13G| lr:6.00e-04| loss_qfl:0.2198| loss_bbox:0.3434| loss_dfl:0.1956|
# [NanoDet][02-09 10:25:24]INFO:Train|Epoch38/100|Iter300(5/273)| mem:5.13G| lr:6.00e-04| loss_qfl:0.2198| loss_bbox:0.3434| loss_dfl:0.1956|
# INFO:NanoDet:Train|Epoch38/100|Iter300(5/273)| mem:5.13G| lr:6.00e-04| loss_qfl:0.2198| loss_bbox:0.3434| loss_dfl:0.1956|
# [NanoDet][02-09 10:25:36]INFO:Train|Epoch41/100|Iter325(6/273)| mem:5.13G| lr:6.50e-04| loss_qfl:0.2247| loss_bbox:0.2820| loss_dfl:0.1825|
# [NanoDet][02-09 10:25:36]INFO:Train|Epoch41/100|Iter325(6/273)| mem:5.13G| lr:6.50e-04| loss_qfl:0.2247| loss_bbox:0.2820| loss_dfl:0.1825|
# INFO:NanoDet:Train|Epoch41/100|Iter325(6/273)| mem:5.13G| lr:6.50e-04| loss_qfl:0.2247| loss_bbox:0.2820| loss_dfl:0.1825|
# [NanoDet][02-09 10:25:48]INFO:Train|Epoch44/100|Iter350(7/273)| mem:5.13G| lr:7.00e-04| loss_qfl:0.1785| loss_bbox:0.2652| loss_dfl:0.1710|
# [NanoDet][02-09 10:25:48]INFO:Train|Epoch44/100|Iter350(7/273)| mem:5.13G| lr:7.00e-04| loss_qfl:0.1785| loss_bbox:0.2652| loss_dfl:0.1710|
# INFO:NanoDet:Train|Epoch44/100|Iter350(7/273)| mem:5.13G| lr:7.00e-04| loss_qfl:0.1785| loss_bbox:0.2652| loss_dfl:0.1710|
# [NanoDet][02-09 10:26:01]INFO:Train|Epoch47/100|Iter375(8/273)| mem:5.13G| lr:7.50e-04| loss_qfl:0.2230| loss_bbox:0.3374| loss_dfl:0.1918|
# [NanoDet][02-09 10:26:01]INFO:Train|Epoch47/100|Iter375(8/273)| mem:5.13G| lr:7.50e-04| loss_qfl:0.2230| loss_bbox:0.3374| loss_dfl:0.1918|
# INFO:NanoDet:Train|Epoch47/100|Iter375(8/273)| mem:5.13G| lr:7.50e-04| loss_qfl:0.2230| loss_bbox:0.3374| loss_dfl:0.1918|
# [NanoDet][02-09 10:26:14]INFO:Train|Epoch51/100|Iter400(1/273)| mem:5.13G| lr:8.00e-04| loss_qfl:0.2046| loss_bbox:0.2810| loss_dfl:0.1802|
# [NanoDet][02-09 10:26:14]INFO:Train|Epoch51/100|Iter400(1/273)| mem:5.13G| lr:8.00e-04| loss_qfl:0.2046| loss_bbox:0.2810| loss_dfl:0.1802|
# INFO:NanoDet:Train|Epoch51/100|Iter400(1/273)| mem:5.13G| lr:8.00e-04| loss_qfl:0.2046| loss_bbox:0.2810| loss_dfl:0.1802|
# [NanoDet][02-09 10:26:25]INFO:Train|Epoch54/100|Iter425(2/273)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1697| loss_bbox:0.3372| loss_dfl:0.1883|
# [NanoDet][02-09 10:26:25]INFO:Train|Epoch54/100|Iter425(2/273)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1697| loss_bbox:0.3372| loss_dfl:0.1883|
# INFO:NanoDet:Train|Epoch54/100|Iter425(2/273)| mem:5.13G| lr:8.50e-04| loss_qfl:0.
273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1726| loss_bbox:0.2966| loss_dfl:0.1732|
# [NanoDet][02-09 10:28:03]INFO:Train|Epoch79/100|Iter625(2/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1944| loss_bbox:0.2471| loss_dfl:0.1620|
# [NanoDet][02-09 10:28:03]INFO:Train|Epoch79/100|Iter625(2/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1944| loss_bbox:0.2471| loss_dfl:0.1620|
# INFO:NanoDet:Train|Epoch79/100|Iter625(2/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1944| loss_bbox:0.2471| loss_dfl:0.1620|
# [NanoDet][02-09 10:28:15]INFO:Train|Epoch82/100|Iter650(3/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1563| loss_bbox:0.2592| loss_dfl:0.1648|
# [NanoDet][02-09 10:28:15]INFO:Train|Epoch82/100|Iter650(3/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1563| loss_bbox:0.2592| loss_dfl:0.1648|
# INFO:NanoDet:Train|Epoch82/100|Iter650(3/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1563| loss_bbox:0.2592| loss_dfl:0.1648|
# [NanoDet][02-09 10:28:27]INFO:Train|Epoch85/100|Iter675(4/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1683| loss_bbox:0.2446| loss_dfl:0.1663|
# [NanoDet][02-09 10:28:27]INFO:Train|Epoch85/100|Iter675(4/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1683| loss_bbox:0.2446| loss_dfl:0.1663|
# INFO:NanoDet:Train|Epoch85/100|Iter675(4/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1683| loss_bbox:0.2446| loss_dfl:0.1663|
# [NanoDet][02-09 10:28:39]INFO:Train|Epoch88/100|Iter700(5/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1605| loss_bbox:0.2597| loss_dfl:0.1659|
# [NanoDet][02-09 10:28:39]INFO:Train|Epoch88/100|Iter700(5/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1605| loss_bbox:0.2597| loss_dfl:0.1659|
# INFO:NanoDet:Train|Epoch88/100|Iter700(5/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1605| loss_bbox:0.2597| loss_dfl:0.1659|
# [NanoDet][02-09 10:28:51]INFO:Train|Epoch91/100|Iter725(6/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1715| loss_bbox:0.2826| loss_dfl:0.1705|
# [NanoDet][02-09 10:28:51]INFO:Train|Epoch91/100|Iter725(6/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1715| loss_bbox:0.2826| loss_dfl:0.1705|
# INFO:NanoDet:Train|Epoch91/100|Iter725(6/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1715| loss_bbox:0.2826| loss_dfl:0.1705|
# [NanoDet][02-09 10:29:03]INFO:Train|Epoch94/100|Iter750(7/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1653| loss_bbox:0.2746| loss_dfl:0.1734|
# [NanoDet][02-09 10:29:03]INFO:Train|Epoch94/100|Iter750(7/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1653| loss_bbox:0.2746| loss_dfl:0.1734|
# INFO:NanoDet:Train|Epoch94/100|Iter750(7/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1653| loss_bbox:0.2746| loss_dfl:0.1734|
# [NanoDet][02-09 10:29:15]INFO:Train|Epoch97/100|Iter775(8/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1662| loss_bbox:0.2519| loss_dfl:0.1685|
# [NanoDet][02-09 10:29:15]INFO:Train|Epoch97/100|Iter775(8/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1662| loss_bbox:0.2519| loss_dfl:0.1685|
# INFO:NanoDet:Train|Epoch97/100|Iter775(8/273)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1662| loss_bbox:0.2519| loss_dfl:0.1685|
# `Trainer.fit` stopped: `max_epochs=100` reached.
# [NanoDet][02-09 10:29:27]INFO:Starting task2
# [NanoDet][02-09 10:29:27]INFO:Starting task2
# [NanoDet][02-09 10:29:27]INFO:Starting task2
# INFO:NanoDet:Starting task2
# [NanoDet][02-09 10:29:27]INFO:Setting up data...
# [NanoDet][02-09 10:29:27]INFO:Setting up data...
# [NanoDet][02-09 10:29:27]INFO:Setting up data...
# INFO:NanoDet:Setting up data...
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'sheep', 'id': 17, 'name': 'sheep'}]!
# Updating buffer dataset
# cfg/task2.yml
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'aeroplane', 'id': 1, 'name': 'aeroplane'}, {'supercategory': 'bicycle', 'id': 2, 'name': 'bicycle'}, {'supercategory': 'bird', 'id': 3, 'name': 'bird'}, {'supercategory': 'boat', 'id': 4, 'name': 'boat'}, {'supercategory': 'bottle', 'id': 5, 'name': 'bottle'}, {'supercategory': 'bus', 'id': 6, 'name': 'bus'}, {'supercategory': 'car', 'id': 7, 'name': 'car'}, {'supercategory': 'cat', 'id': 8, 'name': 'cat'}, {'supercategory': 'chair', 'id': 9, 'name': 'chair'}, {'supercategory': 'cow', 'id': 10, 'name': 'cow'}, {'supercategory': 'diningtable', 'id': 11, 'name': 'diningtable'}, {'supercategory': 'dog', 'id': 12, 'name': 'dog'}, {'supercategory': 'horse', 'id': 13, 'name': 'horse'}, {'supercategory': 'motorbike', 'id': 14, 'name': 'motorbike'}, {'supercategory': 'person', 'id': 15, 'name': 'person'}, {'supercategory': 'pottedplant', 'id': 16, 'name': 'pottedplant'}, {'supercategory': 'sheep', 'id': 17, 'name': 'sheep'}]!
# Load 97 xml files and 353 boxes
# creating index...
# index created!
# [NanoDet][02-09 10:29:28]INFO:Creating model...
# [NanoDet][02-09 10:29:28]INFO:Creating model...
# [NanoDet][02-09 10:29:28]INFO:Creating model...
# INFO:NanoDet:Creating model...
# Load 4605 xml files and 13917 boxes
# creating index...
# index created!
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# [NanoDet][02-09 10:29:28]INFO:Loaded model weight from models/task1/model_last.ckpt
# [NanoDet][02-09 10:29:28]INFO:Loaded model weight from models/task1/model_last.ckpt
# [NanoDet][02-09 10:29:28]INFO:Loaded model weight from models/task1/model_last.ckpt
# INFO:NanoDet:Loaded model weight from models/task1/model_last.ckpt
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
#
#   | Name  | Type        | Params
# --------------------------------------
# 0 | model | NanoDetPlus | 1.2 M
# --------------------------------------
# 1.2 M     Trainable params
# 0         Non-trainable params
# 1.2 M     Total params
# 4.699     Total estimated model params size (MB)
# [NanoDet][02-09 10:29:29]INFO:Train|Epoch1/100|Iter0(1/97)| mem:4.33G| lr:1.00e-07| loss_qfl:0.6336| loss_bbox:0.2936| loss_dfl:0.1697|
# [NanoDet][02-09 10:29:29]INFO:Train|Epoch1/100|Iter0(1/97)| mem:4.33G| lr:1.00e-07| loss_qfl:0.6336| loss_bbox:0.2936| loss_dfl:0.1697|
# [NanoDet][02-09 10:29:29]INFO:Train|Epoch1/100|Iter0(1/97)| mem:4.33G| lr:1.00e-07| loss_qfl:0.6336| loss_bbox:0.2936| loss_dfl:0.1697|
# INFO:NanoDet:Train|Epoch1/100|Iter0(1/97)| mem:4.33G| lr:1.00e-07| loss_qfl:0.6336| loss_bbox:0.2936| loss_dfl:0.1697|
# [NanoDet][02-09 10:30:20]INFO:Train|Epoch9/100|Iter25(2/97)| mem:5.13G| lr:5.01e-05| loss_qfl:0.5941| loss_bbox:0.2599| loss_dfl:0.1601|
# [NanoDet][02-09 10:30:20]INFO:Train|Epoch9/100|Iter25(2/97)| mem:5.13G| lr:5.01e-05| loss_qfl:0.5941| loss_bbox:0.2599| loss_dfl:0.1601|
| mem:5.13G| lr:5.50e-04| loss_qfl:0.1354| loss_bbox:0.2378| loss_dfl:0.1601|
# [NanoDet][02-09 10:33:00]INFO:Train|Epoch92/100|Iter275(3/97)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1354| loss_bbox:0.2378| loss_dfl:0.1601|
# [NanoDet][02-09 10:33:00]INFO:Train|Epoch92/100|Iter275(3/97)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1354| loss_bbox:0.2378| loss_dfl:0.1601|
# INFO:NanoDet:Train|Epoch92/100|Iter275(3/97)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1354| loss_bbox:0.2378| loss_dfl:0.1601|
# `Trainer.fit` stopped: `max_epochs=100` reached.
# [NanoDet][02-09 10:33:16]INFO:Starting task3
# [NanoDet][02-09 10:33:16]INFO:Starting task3
# [NanoDet][02-09 10:33:16]INFO:Starting task3
# [NanoDet][02-09 10:33:16]INFO:Starting task3
# INFO:NanoDet:Starting task3
# [NanoDet][02-09 10:33:16]INFO:Setting up data...
# [NanoDet][02-09 10:33:16]INFO:Setting up data...
# [NanoDet][02-09 10:33:16]INFO:Setting up data...
# [NanoDet][02-09 10:33:16]INFO:Setting up data...
# INFO:NanoDet:Setting up data...
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'sofa', 'id': 18, 'name': 'sofa'}]!
# Updating buffer dataset
# cfg/task3.yml
# WARNING:root:WARNING! Keeping only annotations of these categories [{'supercategory': 'aeroplane', 'id': 1, 'name': 'aeroplane'}, {'supercategory': 'bicycle', 'id': 2, 'name': 'bicycle'}, {'supercategory': 'bird', 'id': 3, 'name': 'bird'}, {'supercategory': 'boat', 'id': 4, 'name': 'boat'}, {'supercategory': 'bottle', 'id': 5, 'name': 'bottle'}, {'supercategory': 'bus', 'id': 6, 'name': 'bus'}, {'supercategory': 'car', 'id': 7, 'name': 'car'}, {'supercategory': 'cat', 'id': 8, 'name': 'cat'}, {'supercategory': 'chair', 'id': 9, 'name': 'chair'}, {'supercategory': 'cow', 'id': 10, 'name': 'cow'}, {'supercategory': 'diningtable', 'id': 11, 'name': 'diningtable'}, {'supercategory': 'dog', 'id': 12, 'name': 'dog'}, {'supercategory': 'horse', 'id': 13, 'name': 'horse'}, {'supercategory': 'motorbike', 'id': 14, 'name': 'motorbike'}, {'supercategory': 'person', 'id': 15, 'name': 'person'}, {'supercategory': 'pottedplant', 'id': 16, 'name': 'pottedplant'}, {'supercategory': 'sheep', 'id': 17, 'name': 'sheep'}, {'supercategory': 'sofa', 'id': 18, 'name': 'sofa'}]!
# Load 372 xml files and 425 boxes
# creating index...
# index created!
# [NanoDet][02-09 10:33:16]INFO:Creating model...
# [NanoDet][02-09 10:33:16]INFO:Creating model...
# [NanoDet][02-09 10:33:16]INFO:Creating model...
# [NanoDet][02-09 10:33:16]INFO:Creating model...
# INFO:NanoDet:Creating model...
# Load 4669 xml files and 14313 boxes
# creating index...
# index created!
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# [NanoDet][02-09 10:33:17]INFO:Loaded model weight from models/task2/model_last.ckpt
# [NanoDet][02-09 10:33:17]INFO:Loaded model weight from models/task2/model_last.ckpt
# [NanoDet][02-09 10:33:17]INFO:Loaded model weight from models/task2/model_last.ckpt
# [NanoDet][02-09 10:33:17]INFO:Loaded model weight from models/task2/model_last.ckpt
# INFO:NanoDet:Loaded model weight from models/task2/model_last.ckpt
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
#
#   | Name  | Type        | Params
# --------------------------------------
# 0 | model | NanoDetPlus | 1.2 M
# --------------------------------------
# 1.2 M     Trainable params
# 0         Non-trainable params
# 1.2 M     Total params
# 4.699     Total estimated model params size (MB)
# [NanoDet][02-09 10:33:18]INFO:Train|Epoch1/100|Iter0(1/372)| mem:4.33G| lr:1.00e-07| loss_qfl:0.4321| loss_bbox:0.2598| loss_dfl:0.1691|
# [NanoDet][02-09 10:33:18]INFO:Train|Epoch1/100|Iter0(1/372)| mem:4.33G| lr:1.00e-07| loss_qfl:0.4321| loss_bbox:0.2598| loss_dfl:0.1691|
# [NanoDet][02-09 10:33:18]INFO:Train|Epoch1/100|Iter0(1/372)| mem:4.33G| lr:1.00e-07| loss_qfl:0.4321| loss_bbox:0.2598| loss_dfl:0.1691|
# [NanoDet][02-09 10:33:18]INFO:Train|Epoch1/100|Iter0(1/372)| mem:4.33G| lr:1.00e-07| loss_qfl:0.4321| loss_bbox:0.2598| loss_dfl:0.1691|
# INFO:NanoDet:Train|Epoch1/100|Iter0(1/372)| mem:4.33G| lr:1.00e-07| loss_qfl:0.4321| loss_bbox:0.2598| loss_dfl:0.1691|
# Exception ignored in: <function _ConnectionBase.__del__ at 0x7f8d88371990>
# Traceback (most recent call last):
#   File "/home/pasti/anaconda3/envs/nanodet/lib/python3.10/multiprocessing/connection.py", line 132, in __del__
#     self._close()
#   File "/home/pasti/anaconda3/envs/nanodet/lib/python3.10/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# [NanoDet][02-09 10:34:03]INFO:Train|Epoch3/100|Iter25(4/372)| mem:5.13G| lr:5.01e-05| loss_qfl:0.3674| loss_bbox:0.2793| loss_dfl:0.1658|
# [NanoDet][02-09 10:34:03]INFO:Train|Epoch3/100|Iter25(4/372)| mem:5.13G| lr:5.01e-05| loss_qfl:0.3674| loss_bbox:0.2793| loss_dfl:0.1658|
# [NanoDet][02-09 10:34:03]INFO:Train|Epoch3/100|Iter25(4/372)| mem:5.13G| lr:5.01e-05| loss_qfl:0.3674| loss_bbox:0.2793| loss_dfl:0.1658|
# [NanoDet][02-09 10:34:03]INFO:Train|Epoch3/100|Iter25(4/372)| mem:5.13G| lr:5.01e-05| loss_qfl:0.3674| loss_bbox:0.2793| loss_dfl:0.1658|
# INFO:NanoDet:Train|Epoch3/100|Iter25(4/372)| mem:5.13G| lr:5.01e-05| loss_qfl:0.3674| loss_bbox:0.2793| loss_dfl:0.1658|
# [NanoDet][02-09 10:34:13]INFO:Train|Epoch5/100|Iter50(7/372)| mem:5.13G| lr:1.00e-04| loss_qfl:0.3558| loss_bbox:0.2236| loss_dfl:0.1605|
# [NanoDet][02-09 10:34:13]INFO:Train|Epoch5/100|Iter50(7/372)| mem:5.13G| lr:1.00e-04| loss_qfl:0.3558| loss_bbox:0.2236| loss_dfl:0.1605|
# [NanoDet][02-09 10:34:13]INFO:Train|Epoch5/100|Iter50(7/372)| mem:5.13G| lr:1.00e-04| loss_qfl:0.3558| loss_bbox:0.2236| loss_dfl:0.1605|
# [NanoDet][02-09 10:34:13]INFO:Train|Epoch5/100|Iter50(7/372)| mem:5.13G| lr:1.00e-04| loss_qfl:0.3558| loss_bbox:0.2236| loss_dfl:0.1605|
# INFO:NanoDet:Train|Epoch5/100|Iter50(7/372)| mem:5.13G| lr:1.00e-04| loss_qfl:0.3558| loss_bbox:0.2236| loss_dfl:0.1605|
# [NanoDet][02-09 10:34:24]INFO:Train|Epoch7/100|Iter75(10/372)| mem:5.13G| lr:1.50e-04| loss_qfl:0.3599| loss_bbox:0.2317| loss_dfl:0.1590|
# [NanoDet][02-09 10:34:24]INFO:Train|Epoch7/100|Iter75(10/372)| mem:5.13G| lr:1.50e-04| loss_qfl:0.3599| loss_bbox:0.2317| loss_dfl:0.1590|
# [NanoDet][02-09 10:34:24]INFO:Train|Epoch7/100|Iter75(10/372)| mem:5.13G| lr:1.50e-04| loss_qfl:0.3599| loss_bbox:0.2317| loss_dfl:0.1590|
# [NanoDet][02-09 10:34:24]INFO:Train|Epoch7/100|Iter75(10/372)| mem:5.13G| lr:1.50e-04| loss_qfl:0.3599| loss_bbox:0.2317| loss_dfl:0.1590|
# INFO:NanoDet:Train|Epoch7/100|Iter75(10/372)| mem:5.13G| lr:1.50e-04| loss_qfl:0.3599| loss_bbox:0.2317| loss_dfl:0.1590|
# [NanoDet][02-09 10:34:36]INFO:Train|Epoch10/100|Iter100(2/372)| mem:5.13G| lr:2.00e-04| loss_qfl:0.3130| loss_bbox:0.2709| loss_dfl:0.1637|
# [NanoDet][02-09 10:34:36]INFO:Train|Epoch10/100|Iter100(2/372)| mem:5.13G| lr:2.00e-04| loss_qfl:0.3130| loss_bbox:0.2709| loss_dfl:0.1637|
# [NanoDet][02-09 10:34:36]INFO:Train|Epoch10/100|Iter100(2/372)| mem:5.13G| lr:2.00e-04| loss_qfl:0.3130| loss_bbox:0.2709| loss_dfl:0.1637|
# [NanoDet][02-09 10:34:36]INFO:Train|Epoch10/100|Iter100(2/372)| mem:5.13G| lr:2.00e-04| loss_qfl:0.3130| loss_bbox:0.2709| loss_dfl:0.1637|
# INFO:NanoDet:Train|Epoch10/100|Iter100(2/372)| mem:5.13G| lr:2.00e-04| loss_qfl:0.3130| loss_bbox:0.2709| loss_dfl:0.1637|
# [NanoDet][02-09 10:34:46]INFO:Train|Epoch12/100|Iter125(5/372)| mem:5.13G| lr:2.50e-04| loss_qfl:0.3192| loss_bbox:0.2442| loss_dfl:0.1664|
# [NanoDet][02-09 10:34:46]INFO:Train|Epoch12/100|Iter125(5/372)| mem:5.13G| lr:2.50e-04| loss_qfl:0.3192| loss_bbox:0.2442| loss_dfl:0.1664|
# [NanoDet][02-09 10:34:46]INFO:Train|Epoch12/100|Iter125(5/372)| mem:5.13G| lr:2.50e-04| loss_qfl:0.3192| loss_bbox:0.2442| loss_dfl:0.1664|
# [NanoDet][02-09 10:34:46]INFO:Train|Epoch12/100|Iter125(5/372)| mem:5.13G| lr:2.50e-04| loss_qfl:0.3192| loss_bbox:0.2442| loss_dfl:0.1664|
# INFO:NanoDet:Train|Epoch12/100|Iter125(5/372)| mem:5.13G| lr:2.50e-04| loss_qfl:0.3192| loss_bbox:0.2442| loss_dfl:0.1664|
# [NanoDet][02-09 10:34:57]INFO:Train|Epoch14/100|Iter150(8/372)| mem:5.13G| lr:3.00e-04| loss_qfl:0.2450| loss_bbox:0.2378| loss_dfl:0.1576|
# [NanoDet][02-09 10:34:57]INFO:Train|Epoch14/100|Iter150(8/372)| mem:5.13G| lr:3.00e-04| loss_qfl:0.2450| loss_bbox:0.2378| loss_dfl:0.1576|
# [NanoDet][02-09 10:34:57]INFO:Train|Epoch14/100|Iter150(8/372)| mem:5.13G| lr:3.00e-04| loss_qfl:0.2450| loss_bbox:0.2378| loss_dfl:0.1576|
# [NanoDet][02-09 10:34:57]INFO:Train|Epoch14/100|Iter150(8/372)| mem:5.13G| lr:3.00e-04| loss_qfl:0.2450| loss_bbox:0.2378| loss_dfl:0.1576|
# INFO:NanoDet:Train|Epoch14/100|Iter150(8/372)| mem:5.13G| lr:3.00e-04| loss_qfl:0.2450| loss_bbox:0.2378| loss_dfl:0.1576|
# [NanoDet][02-09 10:35:07]INFO:Train|Epoch16/100|Iter175(11/372)| mem:5.13G| lr:3.50e-04| loss_qfl:0.1938| loss_bbox:0.2256| loss_dfl:0.1577|
# [NanoDet][02-09 10:35:07]INFO:Train|Epoch16/100|Iter175(11/372)| mem:5.13G| lr:3.50e-04| loss_qfl:0.1938| loss_bbox:0.2256| loss_dfl:0.1577|
# [NanoDet][02-09 10:35:07]INFO:Train|Epoch16/100|Iter175(11/372)| mem:5.13G| lr:3.50e-04| loss_qfl:0.1938| loss_bbox:0.2256| loss_dfl:0.1577|
# [NanoDet][02-09 10:35:07]INFO:Train|Epoch16/100|Iter175(11/372)| mem:5.13G| lr:3.50e-04| loss_qfl:0.1938| loss_bbox:0.2256| loss_dfl:0.1577|
# INFO:NanoDet:Train|Epoch16/100|Iter175(11/372)| mem:5.13G| lr:3.50e-04| loss_qfl:0.1938| loss_bbox:0.2256| loss_dfl:0.1577|
# [NanoDet][02-09 10:35:18]INFO:Train|Epoch19/100|Iter200(3/372)| mem:5.13G| lr:4.00e-04| loss_qfl:0.2059| loss_bbox:0.2112| loss_dfl:0.1499|
# [NanoDet][02-09 10:35:18]INFO:Train|Epoch19/100|Iter200(3/372)| mem:5.13G| lr:4.00e-04| loss_qfl:0.2059| loss_bbox:0.2112| loss_dfl:0.1499|
# [NanoDet][02-09 10:35:18]INFO:Train|Epoch19/100|Iter200(3/372)| mem:5.13G| lr:4.00e-04| loss_qfl:0.2059| loss_bbox:0.2112| loss_dfl:0.1499|
# [NanoDet][02-09 10:35:18]INFO:Train|Epoch19/100|Iter200(3/372)| mem:5.13G| lr:4.00e-04| loss_qfl:0.2059| loss_bbox:0.2112| loss_dfl:0.1499|
# INFO:NanoDet:Train|Epoch19/100|Iter200(3/372)| mem:5.13G| lr:4.00e-04| loss_qfl:0.2059| loss_bbox:0.2112| loss_dfl:0.1499|
# [NanoDet][02-09 10:35:29]INFO:Train|Epoch21/100|Iter225(6/372)| mem:5.13G| lr:4.50e-04| loss_qfl:0.1690| loss_bbox:0.2112| loss_dfl:0.1616|
# [NanoDet][02-09 10:35:29]INFO:Train|Epoch21/100|Iter225(6/372)| mem:5.13G| lr:4.50e-04| loss_qfl:0.1690| loss_bbox:0.2112| loss_dfl:0.1616|
# [NanoDet][02-09 10:35:29]INFO:Train|Epoch21/100|Iter225(6/372)| mem:5.13G| lr:4.50e-04| loss_qfl:0.1690| loss_bbox:0.2112| loss_dfl:0.1616|
# [NanoDet][02-09 10:35:29]INFO:Train|Epoch21/100|Iter225(6/372)| mem:5.13G| lr:4.50e-04| loss_qfl:0.1690| loss_bbox:0.2112| loss_dfl:0.1616|
# INFO:NanoDet:Train|Epoch21/100|Iter225(6/372)| mem:5.13G| lr:4.50e-04| loss_qfl:0.1690| loss_bbox:0.2112| loss_dfl:0.1616|
# [NanoDet][02-09 10:35:39]INFO:Train|Epoch23/100|Iter250(9/372)| mem:5.13G| lr:5.00e-04| loss_qfl:0.1690| loss_bbox:0.2270| loss_dfl:0.1591|
# [NanoDet][02-09 10:35:39]INFO:Train|Epoch23/100|Iter250(9/372)| mem:5.13G| lr:5.00e-04| loss_qfl:0.1690| loss_bbox:0.2270| loss_dfl:0.1591|
# [NanoDet][02-09 10:35:39]INFO:Train|Epoch23/100|Iter250(9/372)| mem:5.13G| lr:5.00e-04| loss_qfl:0.1690| loss_bbox:0.2270| loss_dfl:0.1591|
# [NanoDet][02-09 10:35:39]INFO:Train|Epoch23/100|Iter250(9/372)| mem:5.13G| lr:5.00e-04| loss_qfl:0.1690| loss_bbox:0.2270| loss_dfl:0.1591|
# INFO:NanoDet:Train|Epoch23/100|Iter250(9/372)| mem:5.13G| lr:5.00e-04| loss_qfl:0.1690| loss_bbox:0.2270| loss_dfl:0.1591|
# [NanoDet][02-09 10:35:51]INFO:Train|Epoch26/100|Iter275(1/372)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1819| loss_bbox:0.2034| loss_dfl:0.1506|
# [NanoDet][02-09 10:35:51]INFO:Train|Epoch26/100|Iter275(1/372)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1819| loss_bbox:0.2034| loss_dfl:0.1506|
# [NanoDet][02-09 10:35:51]INFO:Train|Epoch26/100|Iter275(1/372)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1819| loss_bbox:0.2034| loss_dfl:0.1506|
# [NanoDet][02-09 10:35:51]INFO:Train|Epoch26/100|Iter275(1/372)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1819| loss_bbox:0.2034| loss_dfl:0.1506|
# INFO:NanoDet:Train|Epoch26/100|Iter275(1/372)| mem:5.13G| lr:5.50e-04| loss_qfl:0.1819| loss_bbox:0.2034| loss_dfl:0.1506|
# [NanoDet][02-09 10:36:01]INFO:Train|Epoch28/100|Iter300(4/372)| mem:5.13G| lr:6.00e-04| loss_qfl:0.1727| loss_bbox:0.2155| loss_dfl:0.1489|
# [NanoDet][02-09 10:36:01]INFO:Train|Epoch28/100|Iter300(4/372)| mem:5.13G| lr:6.00e-04| loss_qfl:0.1727| loss_bbox:0.2155| loss_dfl:0.1489|
# [NanoDet][02-09 10:36:01]INFO:Train|Epoch28/100|Iter300(4/372)| mem:5.13G| lr:6.00e-04| loss_qfl:0.1727| loss_bbox:0.2155| loss_dfl:0.1489|
# [NanoDet][02-09 10:36:01]INFO:Train|Epoch28/100|Iter300(4/372)| mem:5.13G| lr:6.00e-04| loss_qfl:0.1727| loss_bbox:0.2155| loss_dfl:0.1489|
# INFO:NanoDet:Train|Epoch28/100|Iter300(4/372)| mem:5.13G| lr:6.00e-04| loss_qfl:0.1727| loss_bbox:0.2155| loss_dfl:0.1489|
# [NanoDet][02-09 10:36:11]INFO:Train|Epoch30/100|Iter325(7/372)| mem:5.13G| lr:6.50e-04| loss_qfl:0.1681| loss_bbox:0.2458| loss_dfl:0.1614|
# [NanoDet][02-09 10:36:11]INFO:Train|Epoch30/100|Iter325(7/372)| mem:5.13G| lr:6.50e-04| loss_qfl:0.1681| loss_bbox:0.2458| loss_dfl:0.1614|
# [NanoDet][02-09 10:36:11]INFO:Train|Epoch30/100|Iter325(7/372)| mem:5.13G| lr:6.50e-04| loss_qfl:0.1681| loss_bbox:0.2458| loss_dfl:0.1614|
# [NanoDet][02-09 10:36:11]INFO:Train|Epoch30/100|Iter325(7/372)| mem:5.13G| lr:6.50e-04| loss_qfl:0.1681| loss_bbox:0.2458| loss_dfl:0.1614|
# INFO:NanoDet:Train|Epoch30/100|Iter325(7/372)| mem:5.13G| lr:6.50e-04| loss_qfl:0.1681| loss_bbox:0.2458| loss_dfl:0.1614|
# [NanoDet][02-09 10:36:22]INFO:Train|Epoch32/100|Iter350(10/372)| mem:5.13G| lr:7.00e-04| loss_qfl:0.1634| loss_bbox:0.2273| loss_dfl:0.1536|
# [NanoDet][02-09 10:36:22]INFO:Train|Epoch32/100|Iter350(10/372)| mem:5.13G| lr:7.00e-04| loss_qfl:0.
| mem:5.13G| lr:9.00e-04| loss_qfl:0.1822| loss_bbox:0.2173| loss_dfl:0.1593|
# [NanoDet][02-09 10:37:16]INFO:Train|Epoch44/100|Iter475(3/372)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1662| loss_bbox:0.2321| loss_dfl:0.1535|
# [NanoDet][02-09 10:37:16]INFO:Train|Epoch44/100|Iter475(3/372)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1662| loss_bbox:0.2321| loss_dfl:0.1535|
# [NanoDet][02-09 10:37:16]INFO:Train|Epoch44/100|Iter475(3/372)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1662| loss_bbox:0.2321| loss_dfl:0.1535|
# [NanoDet][02-09 10:37:16]INFO:Train|Epoch44/100|Iter475(3/372)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1662| loss_bbox:0.2321| loss_dfl:0.1535|
# INFO:NanoDet:Train|Epoch44/100|Iter475(3/372)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1662| loss_bbox:0.2321| loss_dfl:0.1535|
# [NanoDet][02-09 10:37:26]INFO:Train|Epoch46/100|Iter500(6/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1510| loss_bbox:0.2533| loss_dfl:0.1546|
# [NanoDet][02-09 10:37:26]INFO:Train|Epoch46/100|Iter500(6/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1510| loss_bbox:0.2533| loss_dfl:0.1546|
# [NanoDet][02-09 10:37:26]INFO:Train|Epoch46/100|Iter500(6/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1510| loss_bbox:0.2533| loss_dfl:0.1546|
# [NanoDet][02-09 10:37:26]INFO:Train|Epoch46/100|Iter500(6/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1510| loss_bbox:0.2533| loss_dfl:0.1546|
# INFO:NanoDet:Train|Epoch46/100|Iter500(6/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1510| loss_bbox:0.2533| loss_dfl:0.1546|
# [NanoDet][02-09 10:37:37]INFO:Train|Epoch48/100|Iter525(9/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1454| loss_bbox:0.2181| loss_dfl:0.1464|
# [NanoDet][02-09 10:37:37]INFO:Train|Epoch48/100|Iter525(9/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1454| loss_bbox:0.2181| loss_dfl:0.1464|
# [NanoDet][02-09 10:37:37]INFO:Train|Epoch48/100|Iter525(9/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1454| loss_bbox:0.2181| loss_dfl:0.1464|
# [NanoDet][02-09 10:37:37]INFO:Train|Epoch48/100|Iter525(9/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1454| loss_bbox:0.2181| loss_dfl:0.1464|
# INFO:NanoDet:Train|Epoch48/100|Iter525(9/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1454| loss_bbox:0.2181| loss_dfl:0.1464|
# [NanoDet][02-09 10:37:49]INFO:Train|Epoch51/100|Iter550(1/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1572| loss_bbox:0.2230| loss_dfl:0.1500|
# [NanoDet][02-09 10:37:49]INFO:Train|Epoch51/100|Iter550(1/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1572| loss_bbox:0.2230| loss_dfl:0.1500|
# [NanoDet][02-09 10:37:49]INFO:Train|Epoch51/100|Iter550(1/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1572| loss_bbox:0.2230| loss_dfl:0.1500|
# [NanoDet][02-09 10:37:49]INFO:Train|Epoch51/100|Iter550(1/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1572| loss_bbox:0.2230| loss_dfl:0.1500|
# INFO:NanoDet:Train|Epoch51/100|Iter550(1/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1572| loss_bbox:0.2230| loss_dfl:0.1500|
# [NanoDet][02-09 10:37:59]INFO:Train|Epoch53/100|Iter575(4/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1461| loss_bbox:0.2232| loss_dfl:0.1476|
# [NanoDet][02-09 10:37:59]INFO:Train|Epoch53/100|Iter575(4/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1461| loss_bbox:0.2232| loss_dfl:0.1476|
# [NanoDet][02-09 10:37:59]INFO:Train|Epoch53/100|Iter575(4/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1461| loss_bbox:0.2232| loss_dfl:0.1476|
# [NanoDet][02-09 10:37:59]INFO:Train|Epoch53/100|Iter575(4/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1461| loss_bbox:0.2232| loss_dfl:0.1476|
# INFO:NanoDet:Train|Epoch53/100|Iter575(4/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1461| loss_bbox:0.2232| loss_dfl:0.1476|
# [NanoDet][02-09 10:38:09]INFO:Train|Epoch55/100|Iter600(7/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1518| loss_bbox:0.2411| loss_dfl:0.1562|
# [NanoDet][02-09 10:38:09]INFO:Train|Epoch55/100|Iter600(7/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1518| loss_bbox:0.2411| loss_dfl:0.1562|
# [NanoDet][02-09 10:38:09]INFO:Train|Epoch55/100|Iter600(7/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1518| loss_bbox:0.2411| loss_dfl:0.1562|
# [NanoDet][02-09 10:38:09]INFO:Train|Epoch55/100|Iter600(7/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1518| loss_bbox:0.2411| loss_dfl:0.1562|
# INFO:NanoDet:Train|Epoch55/100|Iter600(7/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1518| loss_bbox:0.2411| loss_dfl:0.1562|
# [NanoDet][02-09 10:38:20]INFO:Train|Epoch57/100|Iter625(10/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1723| loss_bbox:0.2213| loss_dfl:0.1569|
# [NanoDet][02-09 10:38:20]INFO:Train|Epoch57/100|Iter625(10/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1723| loss_bbox:0.2213| loss_dfl:0.1569|
# [NanoDet][02-09 10:38:20]INFO:Train|Epoch57/100|Iter625(10/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1723| loss_bbox:0.2213| loss_dfl:0.1569|
# [NanoDet][02-09 10:38:20]INFO:Train|Epoch57/100|Iter625(10/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1723| loss_bbox:0.2213| loss_dfl:0.1569|
# INFO:NanoDet:Train|Epoch57/100|Iter625(10/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1723| loss_bbox:0.2213| loss_dfl:0.1569|
# [NanoDet][02-09 10:38:31]INFO:Train|Epoch60/100|Iter650(2/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1482| loss_bbox:0.2048| loss_dfl:0.1512|
# [NanoDet][02-09 10:38:31]INFO:Train|Epoch60/100|Iter650(2/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1482| loss_bbox:0.2048| loss_dfl:0.1512|
# [NanoDet][02-09 10:38:31]INFO:Train|Epoch60/100|Iter650(2/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1482| loss_bbox:0.2048| loss_dfl:0.1512|
# [NanoDet][02-09 10:38:31]INFO:Train|Epoch60/100|Iter650(2/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1482| loss_bbox:0.2048| loss_dfl:0.1512|
# INFO:NanoDet:Train|Epoch60/100|Iter650(2/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1482| loss_bbox:0.2048| loss_dfl:0.1512|
# [NanoDet][02-09 10:38:41]INFO:Train|Epoch62/100|Iter675(5/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1486| loss_bbox:0.2258| loss_dfl:0.1543|
# [NanoDet][02-09 10:38:41]INFO:Train|Epoch62/100|Iter675(5/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1486| loss_bbox:0.2258| loss_dfl:0.1543|
# [NanoDet][02-09 10:38:41]INFO:Train|Epoch62/100|Iter675(5/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1486| loss_bbox:0.2258| loss_dfl:0.1543|
# [NanoDet][02-09 10:38:41]INFO:Train|Epoch62/100|Iter675(5/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1486| loss_bbox:0.2258| loss_dfl:0.1543|
# INFO:NanoDet:Train|Epoch62/100|Iter675(5/372)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1486| loss_bbox:0.2258| loss_dfl:0.1543|
# ...
# [NanoDet][02-09 10:52:32]INFO:Train|Epoch47/100|Iter375(8/279)| mem:5.13G| lr:7.50e-04| loss_qfl:0.1342| loss_bbox:0.2070| loss_dfl:0.1524|
# [NanoDet][02-09 10:52:32]INFO:Train|Epoch47/100|Iter375(8/279)| mem:5.13G| lr:7.50e-04| loss_qfl:0.1342| loss_bbox:0.2070| loss_dfl:0.1524|
# INFO:NanoDet:Train|Epoch47/100|Iter375(8/279)| mem:5.13G| lr:7.50e-04| loss_qfl:0.1342| loss_bbox:0.2070| loss_dfl:0.1524|
# [NanoDet][02-09 10:52:45]INFO:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# [NanoDet][02-09 10:52:45]INFO:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# [NanoDet][02-09 10:52:45]INFO:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# [NanoDet][02-09 10:52:45]INFO:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# [NanoDet][02-09 10:52:45]INFO:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# [NanoDet][02-09 10:52:45]INFO:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# INFO:NanoDet:Train|Epoch51/100|Iter400(1/279)| mem:5.13G| lr:8.00e-04| loss_qfl:0.1451| loss_bbox:0.1846| loss_dfl:0.1512|
# [NanoDet][02-09 10:52:57]INFO:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# [NanoDet][02-09 10:52:57]INFO:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# [NanoDet][02-09 10:52:57]INFO:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# [NanoDet][02-09 10:52:57]INFO:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# [NanoDet][02-09 10:52:57]INFO:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# [NanoDet][02-09 10:52:57]INFO:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# INFO:NanoDet:Train|Epoch54/100|Iter425(2/279)| mem:5.13G| lr:8.50e-04| loss_qfl:0.1617| loss_bbox:0.2281| loss_dfl:0.1559|
# [NanoDet][02-09 10:53:09]INFO:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# [NanoDet][02-09 10:53:09]INFO:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# [NanoDet][02-09 10:53:09]INFO:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# [NanoDet][02-09 10:53:09]INFO:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# [NanoDet][02-09 10:53:09]INFO:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# [NanoDet][02-09 10:53:09]INFO:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# INFO:NanoDet:Train|Epoch57/100|Iter450(3/279)| mem:5.13G| lr:9.00e-04| loss_qfl:0.1602| loss_bbox:0.2131| loss_dfl:0.1545|
# [NanoDet][02-09 10:53:21]INFO:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# [NanoDet][02-09 10:53:21]INFO:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# [NanoDet][02-09 10:53:21]INFO:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# [NanoDet][02-09 10:53:21]INFO:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# [NanoDet][02-09 10:53:21]INFO:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# [NanoDet][02-09 10:53:21]INFO:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# INFO:NanoDet:Train|Epoch60/100|Iter475(4/279)| mem:5.13G| lr:9.50e-04| loss_qfl:0.1481| loss_bbox:0.1990| loss_dfl:0.1492|
# [NanoDet][02-09 10:53:33]INFO:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# [NanoDet][02-09 10:53:33]INFO:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# [NanoDet][02-09 10:53:33]INFO:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# [NanoDet][02-09 10:53:33]INFO:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# [NanoDet][02-09 10:53:33]INFO:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# [NanoDet][02-09 10:53:33]INFO:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# INFO:NanoDet:Train|Epoch63/100|Iter500(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1374| loss_bbox:0.2035| loss_dfl:0.1564|
# [NanoDet][02-09 10:53:45]INFO:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# [NanoDet][02-09 10:53:45]INFO:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# [NanoDet][02-09 10:53:45]INFO:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# [NanoDet][02-09 10:53:45]INFO:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# [NanoDet][02-09 10:53:45]INFO:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# [NanoDet][02-09 10:53:45]INFO:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# INFO:NanoDet:Train|Epoch66/100|Iter525(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1611| loss_bbox:0.2045| loss_dfl:0.1555|
# [NanoDet][02-09 10:53:57]INFO:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# [NanoDet][02-09 10:53:57]INFO:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# [NanoDet][02-09 10:53:57]INFO:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# [NanoDet][02-09 10:53:57]INFO:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# [NanoDet][02-09 10:53:57]INFO:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# [NanoDet][02-09 10:53:57]INFO:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# INFO:NanoDet:Train|Epoch69/100|Iter550(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1612| loss_bbox:0.1975| loss_dfl:0.1494|
# [NanoDet][02-09 10:54:09]INFO:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# [NanoDet][02-09 10:54:09]INFO:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# [NanoDet][02-09 10:54:09]INFO:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# [NanoDet][02-09 10:54:09]INFO:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# [NanoDet][02-09 10:54:09]INFO:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# [NanoDet][02-09 10:54:09]INFO:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# INFO:NanoDet:Train|Epoch72/100|Iter575(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1536| loss_bbox:0.1940| loss_dfl:0.1556|
# [NanoDet][02-09 10:54:22]INFO:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# [NanoDet][02-09 10:54:22]INFO:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# [NanoDet][02-09 10:54:22]INFO:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# [NanoDet][02-09 10:54:22]INFO:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# [NanoDet][02-09 10:54:22]INFO:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# [NanoDet][02-09 10:54:22]INFO:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# INFO:NanoDet:Train|Epoch76/100|Iter600(1/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1332| loss_bbox:0.1983| loss_dfl:0.1475|
# [NanoDet][02-09 10:54:34]INFO:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# [NanoDet][02-09 10:54:34]INFO:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# [NanoDet][02-09 10:54:34]INFO:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# [NanoDet][02-09 10:54:34]INFO:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# [NanoDet][02-09 10:54:34]INFO:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# [NanoDet][02-09 10:54:34]INFO:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# INFO:NanoDet:Train|Epoch79/100|Iter625(2/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1497| loss_bbox:0.2185| loss_dfl:0.1526|
# [NanoDet][02-09 10:54:46]INFO:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# [NanoDet][02-09 10:54:46]INFO:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# [NanoDet][02-09 10:54:46]INFO:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# [NanoDet][02-09 10:54:46]INFO:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# [NanoDet][02-09 10:54:46]INFO:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# [NanoDet][02-09 10:54:46]INFO:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# INFO:NanoDet:Train|Epoch82/100|Iter650(3/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1526| loss_bbox:0.2050| loss_dfl:0.1457|
# [NanoDet][02-09 10:54:58]INFO:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# [NanoDet][02-09 10:54:58]INFO:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# [NanoDet][02-09 10:54:58]INFO:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# [NanoDet][02-09 10:54:58]INFO:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# [NanoDet][02-09 10:54:58]INFO:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# [NanoDet][02-09 10:54:58]INFO:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# INFO:NanoDet:Train|Epoch85/100|Iter675(4/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1142| loss_bbox:0.2099| loss_dfl:0.1492|
# [NanoDet][02-09 10:55:10]INFO:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# [NanoDet][02-09 10:55:10]INFO:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# [NanoDet][02-09 10:55:10]INFO:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# [NanoDet][02-09 10:55:10]INFO:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# [NanoDet][02-09 10:55:10]INFO:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# [NanoDet][02-09 10:55:10]INFO:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# INFO:NanoDet:Train|Epoch88/100|Iter700(5/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1516| loss_bbox:0.1955| loss_dfl:0.1475|
# [NanoDet][02-09 10:55:22]INFO:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# [NanoDet][02-09 10:55:22]INFO:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# [NanoDet][02-09 10:55:22]INFO:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# [NanoDet][02-09 10:55:22]INFO:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# [NanoDet][02-09 10:55:22]INFO:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# [NanoDet][02-09 10:55:22]INFO:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# INFO:NanoDet:Train|Epoch91/100|Iter725(6/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1655| loss_bbox:0.2057| loss_dfl:0.1496|
# [NanoDet][02-09 10:55:34]INFO:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# [NanoDet][02-09 10:55:34]INFO:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# [NanoDet][02-09 10:55:34]INFO:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# [NanoDet][02-09 10:55:34]INFO:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# [NanoDet][02-09 10:55:34]INFO:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# [NanoDet][02-09 10:55:34]INFO:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# INFO:NanoDet:Train|Epoch94/100|Iter750(7/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1312| loss_bbox:0.1882| loss_dfl:0.1392|
# [NanoDet][02-09 10:55:46]INFO:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# [NanoDet][02-09 10:55:46]INFO:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# [NanoDet][02-09 10:55:46]INFO:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# [NanoDet][02-09 10:55:46]INFO:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# [NanoDet][02-09 10:55:46]INFO:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# [NanoDet][02-09 10:55:46]INFO:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# INFO:NanoDet:Train|Epoch97/100|Iter775(8/279)| mem:5.13G| lr:1.00e-03| loss_qfl:0.1413| loss_bbox:0.1933| loss_dfl:0.1509|
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Updating buffer dataset

# %% [markdown]
# # TESTING
#
# To get testing results, use this code in terminal:
# ```bash
# python test.py --task val --config /home/pasti/PycharmProjects/nanodet_cl/eclod/cfg/Replay/task2.yml --model /home/pasti/PycharmProjects/nanodet_cl/eclod/models/Replay/task2/model_last.ckpt
# ```

# %% [markdown]
# # NOTES
