# %% [markdown]
# # How to Load Nanodet in PyTorch
#
# This article is an introductory tutorial to infer nanodet with PyTorch.
#
# **Note**, we suppose this notebook is in the root directory of nonadet!
#
# ## Install nanodet first
#
# For us to begin with, PyTorch should be installed. TorchVision is also required since we will be using it as our model zoo.
#
# A quick solution is to install via pip
#
# ```shell
# pip install torch==1.7.1
# pip install torchvision==0.8.2
# ```
#
# or please refer to official site https://pytorch.org/get-started/locally/
#
# PyTorch versions should be backwards compatible but should be used with the proper TorchVision version.
#
# And then don't forget to install other dependencies.
#
# ```shell
# pip install -r requirements.txt
# ```
#
# Next enter the key part, let's install `nanodet`!
#
# ```shell
# python setup.py develop
# ```
#
# ## Set Environmental Parameters

# %%
import os
import cv2
import torch

device = torch.device('cpu')

# %% [markdown]
# ## Set Model Configuration and Logger

# %%
from nanodet.util import cfg, load_config, Logger

# %%
config_path = '/home/pasti/PycharmProjects/nanodet_cl/eclod/cfg/task1.yml'
model_path = '/home/pasti/PycharmProjects/nanodet_cl/eclod/models/task1/model_best/model_best.ckpt'
image_path = '/home/pasti/Dataset/VOC/VOCtest_06-Nov-2007/VOCdevkit/VOC2007/JPEGImages/000116.jpg'

# %%
load_config(cfg, config_path)
logger = Logger(-1, use_tensorboard=False)

# %% [markdown]
# ## Set Model Predictor

# %%
from demo.demo import Predictor

# %%
predictor = Predictor(cfg, model_path, logger, device=device)
# Out:
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.

# %%
meta, res = predictor.inference(image_path)
# Out:
# forward time: 0.026s | decode time: 0.002s |

# %% [markdown]
# ## Detection output visualisation

# %%
from nanodet.util import overlay_bbox_cv

from IPython.display import display
from PIL import Image

def cv2_imshow(a, convert_bgr_to_rgb=True):
    """A replacement for cv2.imshow() for use in Jupyter notebooks.
    Args:
        a: np.ndarray. shape (N, M) or (N, M, 1) is an NxM grayscale image. shape
            (N, M, 3) is an NxM BGR color image. shape (N, M, 4) is an NxM BGRA color
            image.
        convert_bgr_to_rgb: switch to convert BGR to RGB channel.
    """
    a = a.clip(0, 255).astype('uint8')
    # cv2 stores colors as BGR; convert to RGB
    if convert_bgr_to_rgb and a.ndim == 3:
        if a.shape[2] == 4:
            a = cv2.cvtColor(a, cv2.COLOR_BGRA2RGBA)
        else:
            a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
    display(Image.fromarray(a))

# %%
result = overlay_bbox_cv(meta['raw_img'][0], res[0], , score_thresh=0.35)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 result = overlay_bbox_cv(meta['raw_img'][0], res[0], cfg.class_names, score_thresh=0.35)
#
# File ~/PycharmProjects/nanodet_cl/nanodet/util/visualization.py:38, in overlay_bbox_cv(img, dets, class_names, score_thresh)
#      36 # color = self.cmap(i)[:3]
#      37 color = (_COLORS[label] * 255).astype(np.uint8).tolist()
# ---> 38 text = "{}:{:.1f}%".format(class_names[label], score * 100)
#      39 txt_color = (0, 0, 0) if np.mean(_COLORS[label]) > 0.5 else (255, 255, 255)
#      40 font = cv2.FONT_HERSHEY_SIMPLEX
#
# IndexError: list index out of range

# %%
imshow_scale = 1.0
cv2_imshow(cv2.resize(result, None, fx=imshow_scale, fy=imshow_scale))
# Out:
# <PIL.Image.Image image mode=RGB size=375x500>
